# %%
import os, sys
from dotenv import load_dotenv

# %%
rpath = os.path.abspath('/home/user/Documents/10/w1/tellco')

if rpath not in sys.path:
    sys.path.insert(0, rpath)

import utils.database_manager as db
import utils.data_manager as dataManager

import script.data_cleaner as dataCleaner

# %%
load_dotenv()
database_uri = os.getenv("DATABASE_URI")

# %%
dataM = dataManager.DataManager(database_uri)
# Out:
# Database connection established successfully.

# %%
data = dataM.read_table_to_dataframe('xdr_data')

# %%
data.head(20)
# Out:
#        Bearer Id            Start  Start ms              End  End ms  \
# 0   1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1   1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2   1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3   1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4   1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5   1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6   1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7   1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8   1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9   1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
# 10  7.277826e+18  4/15/2019 10:30      90.0   4/25/2019 6:14   775.0
# 11  1.311448e+19  4/15/2019 11:33     626.0  4/25/2019 18:44   542.0
# 12  1.311448e+19  4/15/2019 12:20     729.0   4/25/2019 8:40   862.0
# ...

# %%
dc = dataCleaner.DataCleaner(data)

# %%
dc.handle_missing_values_numbers()
# Out:
# Error handling missing values: can only concatenate str (not "int") to str
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
# ...

# %%
dc.handle_missing_values_strings()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000  1.304243e+19   4/26/2019 7:25     341.0   4/25/2019 0:01   872.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
dc.remove_duplicates()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000  1.304243e+19   4/26/2019 7:25     341.0   4/25/2019 0:01   872.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
dc.handle_outliers()
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 62      1.304243e+19   4/21/2019 2:55      73.0   4/25/2019 0:17   262.0
# 65      1.311448e+19   4/21/2019 8:26     605.0   4/25/2019 1:20   655.0
# 66      7.349883e+18   4/21/2019 8:54     105.0   4/25/2019 0:48   931.0
# 67      1.311448e+19   4/21/2019 9:19     590.0   4/25/2019 4:42   965.0
# 68      1.304243e+19  4/21/2019 10:09       1.0   4/25/2019 1:39   272.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000  1.304243e+19   4/26/2019 7:25     341.0   4/25/2019 0:01   872.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
dc.normalize_numerical_data()
# Out:
# /home/user/Documents/10/w1/tellco/script/data_cleaner.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[col] = (self.df[col] - self.df[col].min()) / (self.df[col].max() - self.df[col].min())
#         Bearer Id            Start  Start ms              End    End ms  \
# 62       0.977011   4/21/2019 2:55  0.073073   4/25/2019 0:17  0.262262
# 65       0.988506   4/21/2019 8:26  0.605606   4/25/2019 1:20  0.655656
# 66       0.068966   4/21/2019 8:54  0.105105   4/25/2019 0:48  0.931932
# 67       0.988506   4/21/2019 9:19  0.590591   4/25/2019 4:42  0.965966
# 68       0.977011  4/21/2019 10:09  0.001001   4/25/2019 1:39  0.272272
# ...           ...              ...       ...              ...       ...
# ...

# %%
newDM = dataManager.DataManager(os.getenv("CLEANED_DATABASE_URI"))
# Out:
# Database connection established successfully.

# %%
newDM.create_table_from_dataframe(data,'xdr_data')
# Out:
# Dataframe successfully written to the 'xdr_data' table.
# Session closed successfully.
